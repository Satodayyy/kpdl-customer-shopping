# %% [markdown]
# # THÀNH VIÊN 3: ASSOCIATION RULES MINING - MARKET BASKET ANALYSIS
# File: 03_association_rules/association_rules.ipynb

# %% [markdown]
# # ========================================
# # 1. IMPORT LIBRARIES
# # ========================================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
import networkx as nx
from itertools import combinations
import time

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("tab10")

# %% [markdown]
# # ========================================
# # 2. LOAD DATA
# # ========================================
# # ASSOCIATION RULES MINING - MARKET BASKET ANALYSIS

# %%
df = pd.read_csv('cleaned_data (2).csv')
print(f"\n Đã load data: {df.shape[0]:,} transactions")
# Out:
#  Đã load data: 99,457 transactions
